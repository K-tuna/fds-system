# %% [markdown]
# # 0-4: Matplotlib
#
# 데이터 시각화 라이브러리 Matplotlib을 학습합니다.
#
# ## 학습 목표
# 1. 선 그래프 (plot)
# 2. 히스토그램 (hist)
# 3. 막대 그래프 (bar)
# 4. 그래프 꾸미기 (title, label, legend)
# 5. subplot으로 여러 그래프 배치

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# 한글 폰트 설정 (Windows: 맑은 고딕)
plt.rcParams['font.family'] = 'Malgun Gothic'
plt.rcParams['axes.unicode_minus'] = False  # 마이너스 깨짐 방지

# 노트북에서 그래프 바로 표시
# %matplotlib inline

print("✅ 한글 폰트 설정 완료")
# Out:
# ✅ 한글 폰트 설정 완료

# %% [markdown]
# ---
# ## 1. 기초

# %%
# 📚 가장 간단한 그래프
x = [1, 2, 3, 4, 5]
y = [2, 4, 6, 8, 10]

plt.plot(x, y)
plt.show()

# %%
# 📚 figure와 axes
fig, ax = plt.subplots()  # figure: 도화지, ax: 그래프 영역
ax.plot(x, y)
plt.show()

# %% [markdown]
# ---
# ## 2. 선 그래프

# %%
# 📚 선 그래프 옵션
x = np.arange(0, 10, 0.1)
y1 = np.sin(x)
y2 = np.cos(x)

plt.plot(x, y1, 'b-', label='sin')   # 파란 실선
plt.plot(x, y2, 'r--', label='cos')  # 빨간 점선
plt.legend()  # 범례 표시
plt.show()

# %%
# 📚 색상, 스타일 옵션
# 색상: b(파랑), r(빨강), g(초록), k(검정), c(청록), m(마젠타), y(노랑)
# 스타일: -(실선), --(점선), :(점), -.(점선+점)
# 마커: o(원), s(사각), ^(삼각), *(별)

x = [1, 2, 3, 4, 5]
y = [1, 4, 9, 16, 25]

plt.plot(x, y, 'go--', linewidth=2, markersize=10)  # 초록 원 점선
plt.show()

# %% [markdown]
# ### 💻 실습 1: 선 그래프
#
# 월별 거래 건수 추이를 그리세요.

# %%
# 💻 실습 1
months = ['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun']
normal_tx = [1200, 1350, 1100, 1500, 1400, 1600]
fraud_tx = [120, 150, 200, 180, 250, 220]

# TODO: 정상 거래 - 파란 실선, label='정상'
plt.plot(months, normal_tx, 'b-', label='정상')
# TODO: 사기 거래 - 빨간 점선, label='사기'
plt.plot(months, fraud_tx, 'r--', label='사기')
# TODO: 범례 표시
plt.legend()

plt.show()

# %%
# 체크포인트 1
# 그래프가 정상적으로 그려졌는지 육안으로 확인
print("✅ 체크포인트 1: 두 개의 선이 범례와 함께 표시되어야 합니다")

# %% [markdown]
# ---
# ## 3. 히스토그램

# %%
# 📚 히스토그램 기초
data = np.random.randn(1000)  # 정규분포 난수

plt.hist(data, bins=30)  # bins: 막대 개수
plt.show()

# %%
# 📚 히스토그램 옵션
plt.hist(data, bins=30, color='skyblue', edgecolor='black', alpha=0.7)
plt.xlabel('Value')
plt.ylabel('Frequency')
plt.title('Normal Distribution')
plt.show()

# %% [markdown]
# ### 💻 실습 2: 히스토그램
#
# 거래 금액 분포를 히스토그램으로 그리세요.

# %%
# 💻 실습 2
np.random.seed(42)
amounts = np.random.exponential(50000, 1000)  # 지수분포 (소액 거래 많음)

# TODO: 히스토그램 그리기 (bins=50)
plt.hist(amounts, bins=50, color='skyblue', edgecolor='black', alpha=0.7)
# TODO: xlabel='거래금액', ylabel='건수', title='거래금액 분포'
plt.xlabel('거래금액')
plt.ylabel('거래금액 분포')

plt.show()

# %%
# 체크포인트 2
print("✅ 체크포인트 2: 오른쪽으로 긴 꼬리 형태 (소액 거래가 많음)")

# %% [markdown]
# ---
# ## 4. 막대 그래프

# %%
# 📚 막대 그래프
categories = ['A', 'B', 'C', 'D']
values = [25, 40, 30, 55]

plt.bar(categories, values, color='steelblue')
plt.show()

# %%
# 📚 가로 막대 그래프
plt.barh(categories, values, color='coral')
plt.show()

# %% [markdown]
# ### 💻 실습 3: 막대 그래프
#
# 카테고리별 사기 건수를 막대 그래프로 그리세요.

# %%
# 💻 실습 3
categories = ['온라인쇼핑', '해외결제', '새벽시간', '고액결제', '첫거래']
fraud_counts = [45, 78, 32, 56, 23]

# TODO: 막대 그래프 그리기
# TODO: title='카테고리별 사기 건수'
# TODO: xlabel='카테고리', ylabel='건수'


plt.show()

# %%
# 체크포인트 3
print("✅ 체크포인트 3: 해외결제가 가장 높은 막대")

# %% [markdown]
# ---
# ## 5. 그래프 꾸미기

# %%
# 📚 그래프 꾸미기 종합
x = np.linspace(0, 10, 100)
y = np.sin(x)

plt.figure(figsize=(10, 6))  # 크기 설정
plt.plot(x, y, 'b-', linewidth=2)

plt.title('Sine Wave', fontsize=16)  # 제목
plt.xlabel('X axis', fontsize=12)     # x축 라벨
plt.ylabel('Y axis', fontsize=12)     # y축 라벨

plt.xlim(0, 10)   # x축 범위
plt.ylim(-1.5, 1.5)  # y축 범위

plt.grid(True, alpha=0.3)  # 그리드
plt.show()

# %% [markdown]
# ---
# ## 6. Subplot

# %%
# 📚 subplot: 여러 그래프 한번에
fig, axes = plt.subplots(2, 2, figsize=(10, 8))  # 2x2 그리드

# 좌상
axes[0, 0].plot([1, 2, 3], [1, 2, 3])
axes[0, 0].set_title('Line')

# 우상
axes[0, 1].bar(['A', 'B', 'C'], [3, 5, 2])
axes[0, 1].set_title('Bar')

# 좌하
axes[1, 0].hist(np.random.randn(100), bins=20)
axes[1, 0].set_title('Histogram')

# 우하
axes[1, 1].scatter([1, 2, 3, 4], [1, 4, 2, 3])
axes[1, 1].set_title('Scatter')

plt.tight_layout()  # 겹침 방지
plt.show()

# %% [markdown]
# ### 💻 실습 4: Subplot
#
# 1x2 subplot으로 정상/사기 거래 금액 분포를 비교하세요.

# %%
# 💻 실습 4
np.random.seed(42)
normal_amounts = np.random.exponential(30000, 500)   # 정상: 평균 3만원
fraud_amounts = np.random.exponential(150000, 500)   # 사기: 평균 15만원

# TODO: 1x2 subplot 생성 (figsize=(12, 4))
# TODO: 왼쪽 - 정상 거래 히스토그램, title='정상 거래'
# TODO: 오른쪽 - 사기 거래 히스토그램, title='사기 거래'
# TODO: plt.tight_layout()


plt.show()

# %%
# 체크포인트 4
print("✅ 체크포인트 4: 사기 거래가 더 넓게 분포 (고액)")

# %% [markdown]
# ---
# ## ✅ 최종 체크포인트

# %%
print("="*50)
print("🎉 0-4 완료: Matplotlib")
print("="*50)
print()
print("배운 것:")
print("  - 선 그래프: plt.plot()")
print("  - 히스토그램: plt.hist()")
print("  - 막대 그래프: plt.bar()")
print("  - 꾸미기: title, xlabel, ylabel, grid")
print("  - subplot: plt.subplots(rows, cols)")
print()
print("다음: 0-5 ML 개념 + Sklearn")
